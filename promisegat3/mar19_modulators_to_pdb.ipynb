# %%
import requests
import json
import os
import csv
import tempfile
import re
import pandas as pd
from rdkit import Chem
import os


def get_info_from_pubchem(inchikey):
    response = requests.get(
        f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/inchikey/{inchikey}/JSON"
    )
    if response.status_code == 200:
        return response.json()  # Access the JSON data using .json property
    else:
        return None


def get_conformer_ids_from_cid(cid):
    response = requests.get(
        f" https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/{cid}/conformers/JSON"
    )
    if response.status_code == 200:
        return response.json()  # Access the JSON data using .json property
    else:
        return None


def get_sdf_from_conformer_id(conformer_id):
    response = requests.get(
        f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/conformers/{conformer_id}/SDF"
    )
    if response.status_code == 200:
        return response.text  # Access the JSON data using .json property
    else:
        return None


def get_sdf_from_csv(csv_path):
    with open(csv_path, "r") as f:
        reader = csv.reader(f)
        inchikey = None
        for i, row in enumerate(reader):
            if i == 4:
                inchikey = row[1]
                break
        if inchikey is None:
            print("InChIKey not found in the CSV file.")
            return None
    print(inchikey)
    info = get_info_from_pubchem(inchikey)
    if info is None:
        print("Failed to retrieve information from PubChem.")
        return None

    cid = info["PC_Compounds"][0]["id"]["id"]["cid"]
    print(f"Compound ID (CID): {cid}")

    conformer_ids = get_conformer_ids_from_cid(cid)
    if conformer_ids is None:
        print("Failed to retrieve conformer IDs from PubChem.")
        return None
    # print(json.dumps(conformer_ids, indent=4))

    first_conformer_id = conformer_ids["InformationList"]["Information"][0][
        "ConformerID"
    ][0]
    print(f"First Conformer ID: {first_conformer_id}")

    sdf = get_sdf_from_conformer_id(first_conformer_id)
    if sdf is None:
        print("Failed to retrieve SDF data from PubChem.")
        return None

    return sdf, inchikey

def slugify(name):
    return re.sub(r"[\W_.-]+", "-", name)

def process_sdf(sdf, pdb_file_path):
    with tempfile.NamedTemporaryFile(mode="w", delete=False) as temp_sdf_file:
        temp_sdf_file.write(sdf)
    mol_supplier = Chem.SDMolSupplier(temp_sdf_file.name)
    for i, mol in enumerate(mol_supplier):
        if mol is not None:
            Chem.MolToPDBFile(mol, pdb_file_path)
            print(f"Processed {pdb_file_path}")
            return True
    print("mol is none")
    return False


def process_file(root, file, list_of_failures, downloads_path, sdf_to_csv):
    name = None
    try:
        df = pd.read_csv(os.path.join(root, file), header=None)
        name = df.iloc[4, 1]
        pdb_file_path = f"{downloads_path}/{slugify(name)}.pdb"
        print(pdb_file_path)
        open(sdf_to_csv, "a").write(f"{pdb_file_path}\t{os.path.join(root,file)}\n")

    except Exception as e:
        print(f"Reading problem in file {file}: {e}")
        list_of_failures.append(name)
        return False
    if not os.path.exists(pdb_file_path):
        try:
            sdf, inchikey = get_sdf_from_csv(os.path.join(root, file))
            if sdf is not None:
                return process_sdf(sdf, pdb_file_path)
        except Exception as e:
            print(f"Problem processing SDF for file {file}: {e}")
            list_of_failures.append(name)
            return False
    else:
        print(f"File {file} already exists")
        return True

import concurrent.futures

def process_directory(path, downloads_path, sdf_to_csv):
    idx = 0
    total = 0
    success = 0
    already_exist = 0
    failed = 0
    new_added = 0
    list_of_failures = []

    def process_file_wrapper(file):
        nonlocal idx, total, success, already_exist, failed, new_added
        idx += 1
        print(f"idx = {idx}")
        if file.endswith(".csv"):
            total += 1
            if process_file(
                root, file, list_of_failures, downloads_path, sdf_to_csv
            ):
                success += 1
            else:
                failed += 1
        if idx % 50 == 0:
            print(
                f"success = {success}, exist = {already_exist}, failed = {failed}"
            )

    with concurrent.futures.ThreadPoolExecutor() as executor:
        for root, dirs, files in os.walk(path):
            executor.map(process_file_wrapper, files)

    print(f"success = {success}, exist = {already_exist}, failed = {failed}")

# %%
csv_folder = "dlip_files"
inactive_csv_folder = "dlip_files_inactive"
compound_folder = "compound_files"
sdf_to_csv = "sdf_to_csv.txt"
process_directory(csv_folder,compound_folder,sdf_to_csv)
process_directory(inactive_csv_folder,compound_folder,sdf_to_csv)
# Out:
# idx = 1idx = 2
#
# idx = 3
# idx = 4
# idx = 5
# idx = 6
# idx = 7
# idx = 8
# compound_files/CRSZBBYHHDCMTP-UHFFFAOYSA-N.pdb
# compound_files/QSEDWPXFGFLBIO-UHFFFAOYSA-N.pdb
# idx = 9
# compound_files/ZNGZDOVQBYPJEY-UHFFFAOYSA-N.pdb
# compound_files/CKBWTRSIUARPEC-UHFFFAOYSA-N.pdb
# idx = 10
# File compound_I0006Y.csv already exists
# File compound_T0081H.csv already exists
# compound_files/FNOAOFIHRVSHJT-UHFFFAOYSA-N.pdb
# File compound_C101QF.csv already exists
# idx = 11
# idx = 12
# idx = 13
# idx = 14
# idx = 15
# compound_files/BUDMKOHZVRWDQQ-UHFFFAOYSA-N.pdb
# compound_files/OXNCVPXHKUULSH-UHFFFAOYSA-N.pdb
# compound_files/MFZKFMUYNLFXKY-UHFFFAOYSA-N.pdb
# File compound_I000B7.csv already exists
# idx = 16
# File compound_I00068.csv already exists
# idx = 17
# compound_files/BMGQMFHTPSJIIW-UHFFFAOYSA-N.pdb
# compound_files/FOYRFLMZVXPASD-UHFFFAOYSA-N.pdb
# compound_files/ZOMSUTGXSSYGLG-UHFFFAOYSA-N.pdb
# compound_files/FQAUQBOULILEAV-UHFFFAOYSA-N.pdb
# compound_files/FQPKIJJOVFKDLD-KRWDZBQOSA-N.pdb
# compound_files/MLNZGNREXNDJBQ-VQTJNVASSA-N.pdb
# compound_files/MHVOJKFXMPOUON-UHFFFAOYSA-N.pdb
# File compound_I0004Q.csv already exists
# idx = 18
# File compound_T003T3.csv already exists
# idx = 19
# File compound_T004R5.csv already exists
# idx = 20
# File compound_I00040.csv already exists
# File compound_T001L7.csv already exists
# compound_files/ZQLWHZAQJSYSRK-UHFFFAOYSA-N.pdb
# File compound_T001M3.csv already exists
# File compound_T003VM.csv already exists
# idx = 21
# File compound_T00822.csv already exists
# compound_files/UVNKAYDKTALKMK-UHFFFAOYSA-N.pdb
# File compound_T00836.csv already exists
# File compound_T003U7.csv already exists
# compound_files/FTSOGSFFYMFUDT-UHFFFAOYSA-N.pdb
# idx = 22
# compound_files/BLMVYLRHFJSOHW-UHFFFAOYSA-N.pdb
# File compound_T006HO.csv already exists
# compound_files/TYQDALPAKJUICD-UHFFFAOYSA-N.pdb
# File compound_T001LV.csv already exists
# idx = 23
# idx = 24
# idx = 25
# File compound_C101S8.csv already exists
# idx = 26
# idx = 27
# compound_files/DGFFYPGDYTWIMY-KKYDWHDCSA-N.pdb
# File compound_T001NI.csv already exists
# compound_files/DQIWDDWTTROUFW-UHFFFAOYSA-N.pdb
# File compound_C101PB.csv already exists
# compound_files/OTQPSOHVLSUEKO-UHFFFAOYSA-N.pdb
# idx = 28
# compound_files/VDXJYDWZSVLBCU-UHFFFAOYSA-N.pdb
# idx = 29
# File compound_T0015I.csv already exists
# compound_files/OVFGHVHGCRRVCI-UHFFFAOYSA-N.pdb
# idx = 30
# compound_files/MTVXIMCLUYDUHS-UHFFFAOYSA-N.pdb
# File compound_I0009A.csv already exists
# File compound_T004PK.csv already exists
# File compound_C004XH.csv already exists
# idx = 31
# idx = 32
# idx = 33
# File compound_J0000V.csv already exists
# compound_files/SVESXPIJWQQCBW-ZVAWYAOSSA-N.pdb
# compound_files/DPTXHVXUQXOZLC-HOFKKMOUSA-N.pdb
# File compound_T003ZY.csv already exists
# compound_files/SBJPKGCAELSHAV-UHFFFAOYSA-N.pdb
# idx = 34
# File compound_T0061P.csv already exists
# compound_files/MSIZOHMWLYMHPV-LBPRGKRZSA-N.pdb
# idx = 35
# idx = 36
# compound_files/GYQWKTIZRYVFEM-UHFFFAOYSA-N.pdb
# idx = 37
# idx = 38
# File compound_T001AF.csv already exists
# idx = 39
# File compound_C0013A.csv already exists
# idx = 40
# compound_files/NYCQMHOKYBUOQV-UHFFFAOYSA-N.pdb
# File compound_J000D8.csv already exists
# idx = 41
# compound_files/YKUGUWMZBHIDFR-LJQANCHMSA-N.pdb
# compound_files/LFDAKAYNDGVZQG-UHFFFAOYSA-N.pdb
# compound_files/LXRNNOYGXXYOIM-UHFFFAOYSA-N.pdb
# compound_files/LJWYYGATIFNFFR-PMACEKPBSA-N.pdb
# compound_files/URPBTVKRTSDIFK-UHFFFAOYSA-N.pdb
# compound_files/IGKWIHYNVWWXOU-UHFFFAOYSA-N.pdb
# compound_files/VRIFJRKPGQZHJW-UHFFFAOYSA-N.pdb
# MSIZOHMWLYMHPV-LBPRGKRZSA-N
# File compound_J000EJ.csv already exists
# File compound_J000F0.csv already exists
# idx = 42
# File compound_T006FS.csv already exists
# compound_files/XLLVCULLOGKYOO-UHFFFAOYSA-N.pdb
# File compound_T006RA.csv already exists
# File compound_I000OF.csv already exists
# File compound_C001EQ.csv already exists
# idx = 43
# compound_files/PFUCNMYKIVKBEV-UHFFFAOYSA-N.pdb
# idx = 44
# idx = 45
# File compound_I000O0.csv already exists
# idx = 46
# idx = 47
# File compound_T003OX.csv already exists
# File compound_C101IW.csv already exists
# idx = 48
# File compound_C003KO.csv already existscompound_files/BJYAVSZQIJEQQR-KFSOKAEPSA-N.pdb
#
# idx = 49
# idx = 50
# idx = 51
# compound_files/RWOGHLRZYWIIPF-UHFFFAOYSA-N.pdb
# idx = 52
# compound_files/ZJJXGWJIGJFDTL-UHFFFAOYSA-N.pdb
# compound_files/OHYSAAPBMBXXQQ-JZJYNLBNSA-N.pdb
# compound_files/LXJWRDCPNBWJHG-UHFFFAOYSA-N.pdb
# compound_files/KPDIETWHICRCAP-UHFFFAOYSA-N.pdb
# File compound_C004LM.csv already exists
# idx = 53
# compound_files/GOZCVMGQIXTRIT-UHFFFAOYSA-N.pdb
# File compound_T003OO.csv already exists
# idx = 54
# File compound_C003HC.csv already exists
# idx = 55
# compound_files/QBCJHAKYAHFFKF-BOPFTXTBSA-N.pdb
# compound_files/GHSGLKFPNQOGGB-UHFFFAOYSA-N.pdb
# RWOGHLRZYWIIPF-UHFFFAOYSA-N
# File compound_T001XD.csv already exists
# idx = 56
# compound_files/PIHNVMQBEJPYDL-INIZCTEOSA-N.pdb
# File compound_T0039H.csv already exists
# idx = 57
# OHYSAAPBMBXXQQ-JZJYNLBNSA-N
# compound_files/ODFOVGIBIJCVKM-NRFANRHFSA-N.pdb
# compound_files/KMXPGHBUCKVDPS-SFTDATJTSA-N.pdb
# File compound_C0032G.csv already exists
# idx = 58
# File compound_T004HM.csv already exists
# idx = 59
# compound_files/OCQIPBRFVLRAQQ-UHFFFAOYSA-N.pdb
# File compound_I000X9.csv already exists
# idx = 60
# compound_files/ZFMSMUAANRJZFM-UHFFFAOYSA-N.pdb
# compound_files/NKCXFZUAZYBPGA-UHFFFAOYSA-N.pdb
# File compound_J1001W.csv already exists
# idx = 61
# compound_files/KGFVCXSYUNKTSY-UHFFFAOYSA-N.pdb
# File compound_C003DW.csv already exists
# idx = 62
# File compound_I000V2.csv already exists
# idx = 63
# File compound_T001TP.csv already exists
# idx = 64
# compound_files/MXSJSHDIEDILST-UHFFFAOYSA-N.pdb
# compound_files/OHXIQWQDHUUGDR-UHFFFAOYSA-N.pdb
# File compound_I000TL.csv already exists
# idx = 65
# compound_files/SYFLQGBLVFJSKU-UHFFFAOYSA-N.pdb
# File compound_T00361.csv already exists
# idx = 66
# File compound_C004CU.csv already exists
# idx = 67
# File compound_I000VD.csv already exists
# idx = 68
# File compound_T0041R.csv already exists
# idx = 69
# compound_files/KKEMGRLKOQAUBU-KRWDZBQOSA-N.pdb
# compound_files/QKIZLQASTHBCLZ-UHFFFAOYSA-N.pdb
# compound_files/NVRHWELRHNYZOU-QGZVFWFLSA-N.pdb
# compound_files/USDLDJOPUXHGLC-UHFFFAOYSA-N.pdb
# compound_files/CACQVXQRLSNTQI-FQEVSTJZSA-N.pdb
# compound_files/YTUXAQFRBNUADX-RBZQAINGSA-N.pdb
# compound_files/FBGWKDHQIRVFSD-OAHLLOKOSA-N.pdb
# File compound_C005JM.csv already exists
# idx = 70
# File compound_T0037C.csv already exists
# idx = 71
# compound_files/CQGZTNZASZVTQR-CHWSQXEVSA-O.pdb
# File compound_C100NS.csv already exists
# idx = 72
# compound_files/YWCAGHGPKWYRLG-UHFFFAOYSA-N.pdb
# File compound_T0058J.csv already exists
# idx = 73
# File compound_P0003T.csv already exists
# idx = 74
# File compound_J100F5.csv already exists
# idx = 75
# File compound_T000P9.csv already exists
# idx = 76
# File compound_T007UE.csv already exists
# idx = 77
# File compound_P0002P.csv already exists
# idx = 78
# compound_files/RLRVAHVRDIDRIV-KRWDZBQOSA-N.pdb
# compound_files/ZCFGJNKDWNKKRQ-GOSISDBHSA-N.pdb
# compound_files/AONNGYBECNOVTK-SNVBAGLBSA-N.pdb
# compound_files/HVMNEZGNJGWWQS-UHFFFAOYSA-N.pdb
# compound_files/YTOMHMPXLBPXEF-FDIKESKOSA-N.pdb
# compound_files/OBVPFAHIWQLCBQ-UHFFFAOYSA-N.pdb
# compound_files/CKOCFMHNOWHOSU-UHFFFAOYSA-N.pdb
# compound_files/UOPVCDBELHDBLY-UHFFFAOYSA-N.pdb
# File compound_T007WZ.csv already exists
# idx = 79
# File compound_C005JZ.csv already exists
# idx = 80
# compound_files/CAXSRPBPCGUCIY-QHCPKHFHSA-N.pdb
# File compound_C1008T.csv already exists
# idx = 81
# File compound_C100OW.csv already exists
# idx = 82
# File compound_P000GL.csv already exists
# idx = 83
# File compound_T005LE.csv already exists
# idx = 84
# File compound_T007TA.csv already exists
# idx = 85
# compound_files/YWSUTRFYAQHJFZ-UHFFFAOYSA-N.pdb
# File compound_T000PO.csv already exists
# idx = 86
# compound_files/QCAZSKHGEORRCN-UHFFFAOYSA-N.pdb
# File compound_P0000O.csv already exists
# idx = 87
# compound_files/NIDRZGBFOJIVAJ-UHFFFAOYSA-N.pdb
# compound_files/CJXRIVBNRCQKLJ-UHFFFAOYSA-N.pdb
# compound_files/YYPYZVJQCHYCQK-CMOCDZPBSA-N.pdb
# compound_files/RQBROEVOERHIRF-UIOOFZCWSA-N.pdb
# File compound_P000D6.csv already exists
# idx = 88
# File compound_T007UR.csv already exists
# idx = 89
# compound_files/YVUDZGKPSPCYKB-QHCPKHFHSA-N.pdb
# File compound_C100ND.csv already exists
# idx = 90
# File compound_P0002G.csv already exists
# idx = 91
# File compound_T007U3.csv already exists
# idx = 92
# File compound_T005NM.csv already exists
# idx = 93
# compound_files/YUOMCSBLOMSMSI-BQPXYCOLSA-N.pdb
# compound_files/RIBYLXUNNWIWJK-AOMKIAJQSA-N.pdb
# compound_files/YTKGKCKBCJZBIX-UHFFFAOYSA-N.pdb
# YYPYZVJQCHYCQK-CMOCDZPBSA-N
# compound_files/AFUSGLDYQSDIEU-NQIIRXRSSA-N.pdb
# File compound_T007T7.csv already exists
# idx = 94
# File compound_P000E2.csv already exists
# idx = 95
# compound_files/NQXVDDGKDJESCO-UHFFFAOYSA-N.pdb
# compound_files/RZNRQDHAAUZMFW-UHFFFAOYSA-N.pdb
# compound_files/IJNZJGDRYIHSSV-DEOSSOPVSA-N.pdb
# File compound_P00009.csv already exists
# idx = 96
# File compound_T007TV.csv already exists
# idx = 97
# compound_files/YDVVBBHUXDNIKT-UHFFFAOYSA-N.pdb
# compound_files/VKZZMWQUZNYGMS-ISLYRVAYSA-N.pdb
# File compound_C0028S.csv already exists
# idx = 98
# compound_files/GXDYUJHLPNEPQM-UHFFFAOYSA-N.pdb
# File compound_P000ES.csv already exists
# idx = 99
# File compound_T0020P.csv already exists
# idx = 100
# compound_files/WQITZMVRSQPEBE-HMMYKYKNSA-N.pdb
# File compound_T002J5.csv already exists
# success = 89, exist = 0, failed = 0
# idx = 101
# File compound_C005E4.csv already exists
# idx = 102
# compound_files/HDNLLSLLYCIFIU-QAPCUYQASA-N.pdb
# VKZZMWQUZNYGMS-ISLYRVAYSA-N
# File compound_P000IG.csv already exists
# idx = 103
# compound_files/VZTVTSICPINUNG-UHFFFAOYSA-N.pdb
# compound_files/BJVQJZKKPWENLT-UHFFFAOYSA-N.pdb
# File compound_P000HT.csv already exists
# idx = 104
# compound_files/ZCTBUBMRXYVEHX-UHFFFAOYSA-N.pdb
# File compound_T0023K.csv already exists
# idx = 105
# compound_files/IDROMEXQJBMJKF-APHBMKBZSA-N.pdb
# File compound_P000KO.csv already exists
# idx = 106
# File compound_C005GJ.csv already exists
# idx = 107
# compound_files/ZFSXCHHVEXOSLC-UHFFFAOYSA-N.pdb
# compound_files/GYNQANKDGGTNRK-RXFWQSSRSA-N.pdb
# compound_files/UZDLBPIOOFFHSD-UHFFFAOYSA-N.pdb
# File compound_T002G2.csv already exists
# idx = 108
# compound_files/SXPZIMYBDLHEHV-UHFFFAOYSA-N.pdb
# File compound_T007Y0.csv already exists
# idx = 109
# File compound_P000H5.csv already exists
# idx = 110
# compound_files/ZFGAWPWKHQXCEA-UHFFFAOYSA-N.pdb
# File compound_C0052V.csv already exists
# idx = 111
# File compound_T0021C.csv already exists
# idx = 112
# compound_files/IAUBUNZOEUZEQX-UHFFFAOYSA-N.pdb
# compound_files/WDNNGANTDITWSR-UHFFFAOYSA-N.pdb
# compound_files/MDQRZVTXYYTTLF-LICLKQGHSA-N.pdb
# File compound_C0027K.csv already exists
# idx = 113
# compound_files/WSCYUZJLJQNLSQ-UHFFFAOYSA-N.pdb
# File compound_P000IP.csv already exists
# idx = 114
# compound_files/YTCLNFRWWDXEMR-UHFFFAOYSA-N.pdb
# File compound_T002EL.csv already exists
# idx = 115
# compound_files/YJGLQSZEPISCIJ-AWEZNQCLSA-N.pdb
# compound_files/ILJVPKAGGUAOAT-UHFFFAOYSA-N.pdb
# File compound_P000I1.csv already exists
# idx = 116
# compound_files/JAUBDECGBYELOG-UHFFFAOYSA-N.pdb
# File compound_T002PZ.csv already exists
# idx = 117
# compound_files/YAGOLAYHFSZMTF-UHFFFAOYSA-N.pdb
# File compound_I001ER.csv already exists
# idx = 118
# File compound_C002WV.csv already exists
# idx = 119
# File compound_T007XU.csv already exists
# idx = 120
# compound_files/RTJPPXVTEHIEDJ-UHFFFAOYSA-N.pdb
# compound_files/BLZOWNLJBLDRTL-UHFFFAOYSA-N.pdb
# File compound_T000IZ.csv already exists
# idx = 121
# File compound_T007N9.csv already exists
# idx = 122
# File compound_I0012F.csv already exists
# idx = 123
# compound_files/SJRHEVNMVZWOFI-UHFFFAOYSA-N.pdb
# File compound_C1028A.csv already exists
# idx = 124
# compound_files/XWYMWLGPGRAJLM-GPJHCHHRSA-N.pdb
# File compound_T005W9.csv already exists
# idx = 125
# compound_files/GPGOCTLAUAHUQO-UHFFFAOYSA-N.pdb
# XWYMWLGPGRAJLM-GPJHCHHRSA-N
# compound_files/WOXHQCHYDTWCMH-UHFFFAOYSA-N.pdb
# compound_files/VFLDPWHFBUODDF-FCXRPNKRSA-N.pdb
# compound_files/JGKQCWNXJDBDJO-UHFFFAOYSA-N.pdb
# File compound_C1028V.csv already exists
# idx = 126
# File compound_C000MM.csv already exists
# idx = 127
# compound_files/SCEVCEGSVQEIQX-UROBUVALSA-N.pdb
# compound_files/BQSRERXVYLPKDS-IBGZPJMESA-N.pdb
# File compound_T002SV.csv already exists
# idx = 128
# File compound_C000NV.csv already exists
# idx = 129
# File compound_I00134.csv already exists
# idx = 130
# File compound_T000KR.csv already exists
# idx = 131
# compound_files/BLIMBMNFPVTNFS-IBGZPJMESA-N.pdb
# compound_files/SJVHAVXPNJDJPK-UHFFFAOYSA-N.pdb
# compound_files/BOFNJGKNSVAYQM-UHFFFAOYSA-N.pdb
# compound_files/OSAKXIAFCPXTGN-UHFFFAOYSA-N.pdb
# File compound_T000IM.csv already exists
# idx = 132
# compound_files/YWNIWYSIZUOBBC-NBPJVQFTSA-N.pdb
# File compound_I0013U.csv already exists
# idx = 133
# compound_files/YKPCSMLMBOPSAF-YVZMLIKISA-N.pdb
# File compound_T000JV.csv already exists
# idx = 134
# File compound_I001GZ.csv already exists
# idx = 135
# File compound_C1029R.csv already exists
# idx = 136
# compound_files/ZMMBSXODONDQLW-QZTJIDSGSA-N.pdb
# compound_files/WYPGVVZBOCXSCK-NRFANRHFSA-N.pdb
# YKPCSMLMBOPSAF-YVZMLIKISA-N
# compound_files/AGQKPFSCDZOPKE-KRWDZBQOSA-N.pdb
# File compound_T0077P.csv already exists
# idx = 137
# compound_files/BCDVKMOAMMODMM-UHFFFAOYSA-N.pdb
# File compound_T0003I.csv already exists
# idx = 138
# compound_files/RHVPEFQDYMMNSY-UHFFFAOYSA-N.pdb
# ZMMBSXODONDQLW-QZTJIDSGSA-N
# File compound_T000E8.csv already exists
# idx = 139
# File compound_C000BU.csv already exists
# idx = 140
# compound_files/ABWVHMRPSGGLNQ-ZDUSSCGKSA-N.pdb
# compound_files/ACRAUDAJHFBUBH-UHFFFAOYSA-N.pdb
# File compound_T0000R.csv already exists
# idx = 141
# File compound_T0001A.csv already exists
# idx = 142
# compound_files/BFQFATKIIYMFLO-UHFFFAOYSA-N.pdb
# compound_files/BFJJEUZCSKYLAS-UHFFFAOYSA-N.pdb
# compound_files/PHRLXUJXDQNSFA-UHFFFAOYSA-N.pdb
# File compound_T000G0.csv already exists
# idx = 143
# compound_files/WUDMWSRCKXOKCG-AWEZNQCLSA-N.pdb
# File compound_T000FU.csv already exists
# idx = 144
# File compound_C0007I.csv already exists
# idx = 145
# File compound_T00759.csv already exists
# idx = 146
# compound_files/XKMZDPUECWRNRR-UHFFFAOYSA-N.pdb
# compound_files/YYUHVSFHPFDNGR-UHFFFAOYSA-N.pdb
# File compound_T007CH.csv already exists
# idx = 147
# compound_files/WUDMWSRCKXOKCG-AWEZNQCLSA-N.pdb
# File compound_I001HB.csv already exists
# idx = 148
# File compound_T00758.csv already exists
# idx = 149
# compound_files/XEVNETHTGZYGEY-UHFFFAOYSA-N.pdb
# compound_files/BDDCLDRLILJZPQ-UHFFFAOYSA-N.pdb
# compound_files/SOPPFMIUBSUFLF-UHFFFAOYSA-N.pdb
# compound_files/BFQFATKIIYMFLO-UHFFFAOYSA-N.pdb
# File compound_T007A7.csv already exists
# idx = 150
# File compound_T000EO.csv already exists
# success = 139, exist = 0, failed = 0
# idx = 151
# File compound_T005YR.csv already exists
# idx = 152
# File compound_T000G1.csv already exists
# idx = 153
# compound_files/DHDVVMIYKAPBOC-UHFFFAOYSA-N.pdb
# compound_files/WWUJBWRZVJNABY-UHFFFAOYSA-N.pdb
# compound_files/MDNWOSOZYLHTCG-UHFFFAOYSA-N.pdb
# compound_files/BCDVKMOAMMODMM-UHFFFAOYSA-N.pdb
# File compound_T0076U.csv already exists
# idx = 154
# File compound_C002ZP.csv already exists
# idx = 155
# File compound_C0004D.csv already exists
# idx = 156
# File compound_T000E9.csv already exists
# idx = 157
# compound_files/ACAKBZZHDIANCL-FQEVSTJZSA-N.pdb
# compound_files/AGPMOOUJFISFHJ-ZMOGYAJESA-N.pdb
# compound_files/JHBWYQRKOUBPCA-UHFFFAOYSA-N.pdb
# compound_files/ZMECOPHBTSLPQS-UHFFFAOYSA-N.pdb
# File compound_T0003H.csv already exists
# idx = 158
# File compound_I001IP.csv already exists
# idx = 159
# File compound_T0000S.csv already exists
# idx = 160
# File compound_C000BT.csv already exists
# idx = 161
# compound_files/ADZOWOQZYZMJKT-UHFFFAOYSA-N.pdb
# File compound_T0001W.csv already exists
# idx = 162
# compound_files/XDRKIJOIWIDLCP-UHFFFAOYSA-N.pdb
# compound_files/WYPGVVZBOCXSCK-NRFANRHFSA-N.pdb
# File compound_T0077Q.csv already exists
# idx = 163
# compound_files/BGSQJLBMFYVHEF-FQEVSTJZSA-N.pdb
# File compound_T0079Z.csv already exists
# idx = 164
# compound_files/RXCDHJANJVJLRC-ZETCQYMHSA-N.pdb
# File compound_T000GG.csv already exists
# idx = 165
# compound_files/BOFNJGKNSVAYQM-UHFFFAOYSA-N.pdb
# File compound_I0012P.csv already exists
# idx = 166
# compound_files/JEIDTZPERCHWAM-NRFANRHFSA-N.pdb
# File compound_T000JW.csv already exists
# idx = 167
# compound_files/BLIMBMNFPVTNFS-IBGZPJMESA-N.pdb
# File compound_T002RS.csv already exists
# idx = 168
# compound_files/YKMCPWQMUVKGMG-UHFFFAOYSA-N.pdb
# compound_files/XVVYPVQIPXOKCL-UHFFFAOYSA-N.pdb
# File compound_T000IL.csv already exists
# idx = 169
# File compound_C1029S.csv already exists
# idx = 170
# compound_files/BQTUWUXJPAYSPB-AOMKIAJQSA-N.pdb
# XVVYPVQIPXOKCL-UHFFFAOYSA-N
# compound_files/RAHAMDOWXJCPRG-IAGOWNOFSA-N.pdb
# File compound_T000KS.csv already exists
# idx = 171
# compound_files/SUVMJBTUFCVSAD-UHFFFAOYSA-N.pdb
# RAHAMDOWXJCPRG-IAGOWNOFSA-N
# compound_files/RTJPPXVTEHIEDJ-UHFFFAOYSA-N.pdb
# File compound_C1029D.csv already exists
# idx = 172
# File compound_I0012G.csv already exists
# idx = 173
# compound_files/XFAPJIVRXVFTKU-ZETCQYMHSA-N.pdb
# compound_files/YTBKJMLXUZPFIZ-VPZIORFKSA-N.pdb
# File compound_I001D6.csv already exists
# idx = 174
# File compound_I001GL.csv already exists
# idx = 175
# compound_files/SLEGEICAQQRORE-UHFFFAOYSA-N.pdb
# compound_files/XQWKMFVPDAAVEN-UHFFFAOYSA-N.pdb
# File compound_I001DW.csv already exists
# idx = 176
# File compound_T005WY.csv already exists
# idx = 177
# compound_files/QUMQFRXDVDUPEB-HCLLECIRSA-N.pdb
# compound_files/KNJKLBLRJBJXFN-UHFFFAOYSA-N.pdb
# File compound_I00109.csv already exists
# idx = 178
# File compound_C100VT.csv already exists
# idx = 179
# compound_files/XAGPISNWGGUKIZ-UHFFFAOYSA-N.pdb
# compound_files/ZFFDPMCCPRBYOG-UHFFFAOYSA-N.pdb
# File compound_T0078I.csv already exists
# idx = 180
# File compound_T007XT.csv already exists
# idx = 181
# compound_files/QUQSNYWBCOHFKR-HKUYNNGSSA-N.pdb
# compound_files/GXGGKRHOVUZRQG-JQIJEIRASA-N.pdb
# File compound_T005CK.csv already exists
# idx = 182
# File compound_C0051L.csv already exists
# idx = 183
# compound_files/WSWGBAXEVIRMAC-UHFFFAOYSA-N.pdb
# compound_files/OHZOKKGTLRVETE-UHFFFAOYSA-N.pdb
# File compound_P000IQ.csv already exists
# idx = 184
# File compound_C005DG.csv already exists
# idx = 185
# compound_files/UZACLOFDRFURFZ-UHFFFAOYSA-N.pdb
# compound_files/ZCOHGHCESYZASH-UHFFFAOYSA-N.pdb
# File compound_P000H4.csv already exists
# idx = 186
# File compound_P000KN.csv already exists
# idx = 187
# compound_files/WAQHVLNKHJYPKB-JTQLQIEISA-N.pdb
# File compound_P000HU.csv already exists
# idx = 188
# compound_files/GYNQANKDGGTNRK-RXFWQSSRSA-N.pdb
# File compound_T0021B.csv already exists
# idx = 189
# compound_files/ZFSXCHHVEXOSLC-UHFFFAOYSA-N.pdb
# File compound_T007Y1.csv already exists
# idx = 190
# compound_files/GUPDJDZREMBCHF-AWEZNQCLSA-N.pdb
# File compound_T00200.csv already exists
# idx = 191
# compound_files/IBLPGSPXWXVJAM-UYRXBGFRSA-N.pdb
# compound_files/IBZYOIITYJUPHN-UHFFFAOYSA-N.pdb
# File compound_T002FA.csv already exists
# idx = 192
# File compound_T002EZ.csv already exists
# idx = 193
# compound_files/WPKUYRYYDUHEAQ-UHFFFAOYSA-N.pdb
# compound_files/LAQJXNMXIQDUBI-UHFFFAOYSA-N.pdb
# File compound_C1007Z.csv already exists
# idx = 194
# File compound_P000IF.csv already exists
# idx = 195
# compound_files/ZMIAMADGCOUQBT-REZTVBANSA-N.pdb
# compound_files/IEEVNUWUOGCRPK-NSHDSACASA-N.pdb
# File compound_C0026Y.csv already exists
# idx = 196
# File compound_T002GE.csv already exists
# idx = 197
# compound_files/YTKGKCKBCJZBIX-UHFFFAOYSA-N.pdb
# File compound_T007T6.csv already exists
# idx = 198
# compound_files/YUOMCSBLOMSMSI-BQPXYCOLSA-N.pdb
# File compound_T007TW.csv already exists
# idx = 199
# compound_files/RRVWTVVDLQKPSR-UHFFFAOYSA-N.pdb
# compound_files/RLGHFVLWYYVMQZ-BZYZDCJZSA-N.pdb
# File compound_T005L2.csv already exists
# idx = 200
# File compound_T005OH.csv already exists
# success = 189, exist = 0, failed = 0
# idx = 201
# compound_files/IJNZJGDRYIHSSV-DEOSSOPVSA-N.pdb
# compound_files/INLKZOGWBUSMOY-UHFFFAOYSA-N.pdb
# File compound_T002J4.csv already exists
# idx = 202
# File compound_C0028R.csv already exists
# idx = 203
# compound_files/CCEPCRZUBCXDIG-FQEVSTJZSA-N.pdb
# File compound_T000QJ.csv already exists
# idx = 204
# compound_files/RZFVLEJOHSLEFR-UHFFFAOYSA-N.pdb
# File compound_P000ER.csv already exists
# idx = 205
# compound_files/RIUWVQAWHOOGFK-UHFFFAOYSA-N.pdb
# File compound_P000E3.csv already exists
# idx = 206
# compound_files/QCXJEYYXVJIFCE-UHFFFAOYSA-N.pdb
# File compound_P000D7.csv already exists
# idx = 207
# compound_files/ILIJAAWQIUXHNY-DJNXLDHESA-N.pdb
# compound_files/ZYMXKFMDRAJXFM-UHFFFAOYSA-N.pdb
# File compound_T002K0.csv already exists
# idx = 208
# File compound_C1008U.csv already exists
# idx = 209
# compound_files/CAXSRPBPCGUCIY-QHCPKHFHSA-N.pdb
# File compound_T000PN.csv already exists
# idx = 210
# compound_files/CFGADNMKHAGYEI-ZETCQYMHSA-N.pdb
# File compound_T000S4.csv already exists
# idx = 211
# compound_files/YYPYZVJQCHYCQK-CMOCDZPBSA-N.pdb
# compound_files/ROHIWLMIZZHECP-UHFFFAOYSA-N.pdb
# YYPYZVJQCHYCQK-CMOCDZPBSA-N
# File compound_T005MW.csv already exists
# idx = 212
# compound_files/YWSUTRFYAQHJFZ-UHFFFAOYSA-N.pdb
# File compound_T007US.csv already exists
# idx = 213
# compound_files/RMZAKEMVYITRIY-UHFFFAOYSA-N.pdb
# File compound_T005M6.csv already exists
# idx = 214
# compound_files/RQBROEVOERHIRF-UIOOFZCWSA-N.pdb
# File compound_T005NL.csv already exists
# idx = 215
# compound_files/XJFMPFAQHZZJPX-UHFFFAOYSA-N.pdb
# File compound_C100OV.csv already exists
# idx = 216
# compound_files/RLRVAHVRDIDRIV-KRWDZBQOSA-N.pdb
# File compound_T005LD.csv already exists
# idx = 217
# compound_files/DJIRSBLLCJUATA-UHFFFAOYSA-N.pdb
# File compound_P00034.csv already exists
# idx = 218
# compound_files/AMSUHYUVOVCWTP-INIZCTEOSA-N.pdb
# File compound_P0000N.csv already exists
# idx = 219
# compound_files/FBRCDLGEWAXPMI-IWEFOYFVSA-N.pdb
# File compound_P0003U.csv already exists
# idx = 220
# compound_files/RQFUKBAHMUVXDA-UHFFFAOYSA-N.pdb
# File compound_P000EE.csv already exists
# idx = 221
# compound_files/NVRHWELRHNYZOU-KRWDZBQOSA-N.pdb
# File compound_C005JL.csv already exists
# idx = 222
# compound_files/CFUKCNIRQBDDDD-NRFANRHFSA-N.pdb
# File compound_T000SB.csv already exists
# idx = 223
# compound_files/BLNCOMMFECMGRC-UHFFFAOYSA-N.pdb
# File compound_P0001J.csv already exists
# idx = 224
# compound_files/BWDQNSFITDYIRC-UHFFFAOYSA-N.pdb
# File compound_P00020.csv already exists
# idx = 225
# compound_files/CSXFLOZZMPSMKL-UHFFFAOYSA-N.pdb
# File compound_P0002Q.csv already exists
# idx = 226
# compound_files/NVOQWFABHCSZFK-UHFFFAOYSA-N.pdb
# File compound_C100N3.csv already exists
# idx = 227
# compound_files/YWCAGHGPKWYRLG-UHFFFAOYSA-N.pdb
# File compound_T007UD.csv already exists
# idx = 228
# compound_files/RDOWQLZANAYVLL-UHFFFAOYSA-N.pdb
# File compound_C003EE.csv already exists
# idx = 229
# compound_files/ZYLQDVHQXSUVQO-UHFFFAOYSA-N.pdb
# File compound_J100F4.csv already exists
# idx = 230
# compound_files/KSHBMIHYGBWYMH-UHFFFAOYSA-N.pdb
# File compound_T003AR.csv already exists
# idx = 231
# compound_files/JAWGKAWMDVYUQA-AATRIKPKSA-N.pdb
# File compound_C00320.csv already exists
# idx = 232
# compound_files/OICNNGQJJXUBER-DEOSSOPVSA-N.pdb
# OICNNGQJJXUBER-DEOSSOPVSA-N
# Failed to retrieve information from PubChem.
# Problem processing SDF for file compound_T007VI.csv: cannot unpack non-iterable NoneType object
# idx = 233
# compound_files/QELDJEKNFOQJOY-ZDUSSCGKSA-N.pdb
# File compound_C003E3.csv already exists
# idx = 234
# compound_files/KLVKCAIZZUINTK-QFIPXVFZSA-N.pdb
# File compound_T0037U.csv already exists
# idx = 235
# compound_files/NKCXFZUAZYBPGA-UHFFFAOYSA-N.pdb
# File compound_I000TM.csv already exists
# idx = 236
# compound_files/OHZOKKGTLRVETE-UHFFFAOYSA-N.pdb
# File compound_C101GJ.csv already exists
# idx = 237
# compound_files/LKAMDZUYTXTHDM-UHFFFAOYSA-N.pdb
# File compound_C003ER.csv already exists
# idx = 238
# compound_files/KCSFRNPOIBUWHU-UHFFFAOYSA-N.pdb
# File compound_T0034N.csv already exists
# idx = 239
# compound_files/MXSJSHDIEDILST-UHFFFAOYSA-N.pdb
# File compound_T0041S.csv already exists
# idx = 240
# compound_files/KRQGGBHSBXARDG-APTRMMRNSA-N.pdb
# File compound_C004C5.csv already exists
# idx = 241
# compound_files/MWICRKHXHXGESF-DFBJGRDBSA-N.pdb
# File compound_T0040W.csv already exists
# idx = 242
# compound_files/WQURFVOLUVMMKK-WSVSGYBVSA-N.pdb
# File compound_C004B1.csv already exists
# idx = 243
# compound_files/JIYMVSQRGZEYAX-CWUUNJJBSA-N.pdb
# JIYMVSQRGZEYAX-CWUUNJJBSA-N
# Compound ID (CID): 11755157Failed to retrieve information from PubChem.
# Problem processing SDF for file compound_J100HH.csv: cannot unpack non-iterable NoneType object
# idx = 244
#
# compound_files/KFIPSMBXBXMGGF-NRFANRHFSA-N.pdb
# File compound_T0035J.csv already exists
# idx = 245
# compound_files/ODFOVGIBIJCVKM-NRFANRHFSA-N.pdb
# File compound_T004HL.csv already exists
# idx = 246
# compound_files/VSBVRUFXHYLPLE-UHFFFAOYSA-N.pdb
# File compound_T006S2.csv already exists
# idx = 247
# compound_files/LVGIASYHZSVGII-UHFFFAOYSA-N.pdb
# File compound_T003NJ.csv already exists
# idx = 248
# compound_files/PZIXHWCLXXXQIW-UHFFFAOYSA-N.pdb
# PZIXHWCLXXXQIW-UHFFFAOYSA-N
# Failed to retrieve information from PubChem.
# Problem processing SDF for file compound_T007VH.csv: cannot unpack non-iterable NoneType object
# idx = 249
# compound_files/XGFGRZPAZNTMIS-PTLVVNQVSA-N.pdb
# File compound_C004ND.csv already exists
# idx = 250
# compound_files/LOBCDGHHHHGHFA-UHFFFAOYSA-N.pdb
# File compound_C003HB.csv already exists
# success = 236, exist = 0, failed = 3
# idx = 251
# compound_files/OINZSHMABRPILQ-JOCLIGHLSA-N.pdb
# File compound_T004JS.csv already exists
# idx = 252
# compound_files/GKHZEXMYTPRFKV-UHFFFAOYSA-N.pdb
# Compound ID (CID): 168318341
# File compound_T001V8.csv already exists
# idx = 253
# Compound ID (CID): 168318155
# compound_files/LXRNNOYGXXYOIM-UHFFFAOYSA-N.pdb
# File compound_T003OY.csv already exists
# idx = 254
# compound_files/ODKVMWAWCVLXJM-YNCBHJGCSA-N.pdb
# File compound_C004N2.csv already exists
# idx = 255
# compound_files/LWKXOOFAJUSUFC-UHFFFAOYSA-N.pdb
# File compound_T003O8.csv already exists
# idx = 256
# compound_files/LQLRMVRJDVQLGH-UHFFFAOYSA-N.pdb
# File compound_T003LB.csv already exists
# idx = 257
# compound_files/OHTDXSAFYXPXKY-UHFFFAOYSA-O.pdb
# File compound_T004JD.csv already exists
# idx = 258
# compound_files/KPDIETWHICRCAP-UHFFFAOYSA-N.pdb
# File compound_T0039I.csv already exists
# idx = 259
# compound_files/AUNFUILAOBLWAV-UHFFFAOYSA-N.pdb
# File compound_C003KN.csv already exists
# idx = 260
# compound_files/QCLBVGLQKICMSD-UHFFFAOYSA-N.pdb
# File compound_I000YJ.csv already exists
# idx = 261
# compound_files/COFMYJWNXSFLKQ-QIROLCGISA-N.pdb
# File compound_C001PQ.csv already exists
# idx = 262
# compound_files/QIBJARFLROBPQO-KGLIPLIRSA-N.pdb
# File compound_I000Z0.csv already exists
# idx = 263
# compound_files/DPZYMTMUTWSZOW-UHFFFAOYSA-N.pdb
# File compound_T001AP.csv already exists
# idx = 264
# compound_files/XLYAWBZMLNSOBU-UHFFFAOYSA-N.pdb
# File compound_C0013W.csv already exists
# idx = 265
# compound_files/SUTFGPKMGSBIER-FQEVSTJZSA-N.pdb
# File compound_T0061F.csv already exists
# idx = 266
# compound_files/GRFBFSARRYJWSN-FQEVSTJZSA-N.pdb
# GRFBFSARRYJWSN-FQEVSTJZSA-N
# Failed to retrieve information from PubChem.
# Problem processing SDF for file compound_P000HC.csv: cannot unpack non-iterable NoneType object
# idx = 267
# Compound ID (CID): 168317994
# compound_files/DLVMAUPKVXGJIH-HZPDHXFCSA-N.pdb
# DLVMAUPKVXGJIH-HZPDHXFCSA-N
# Compound ID (CID): 168318282
# Compound ID (CID): 168317936
# Compound ID (CID): 9588170
# Failed to retrieve information from PubChem.
# Problem processing SDF for file compound_T004JE.csv: cannot unpack non-iterable NoneType object
# idx = 268
# compound_files/MSJFRVFQMDZEFH-SOFGYWHQSA-N.pdb
# File compound_T003Z9.csv already exists
# idx = 269
# compound_files/MQWGOPKAWPNVQO-CYBMUJFWSA-N.pdb
# File compound_T003YC.csv already exists
# idx = 270
# compound_files/DPTXHVXUQXOZLC-HOFKKMOUSA-N.pdb
# File compound_T001AG.csv already exists
# idx = 271
# compound_files/ZGOOPZVQMLHPFM-UHFFFAOYSA-N.pdb
# File compound_C001EP.csv already exists
# idx = 272
# compound_files/OVFGHVHGCRRVCI-UHFFFAOYSA-N.pdb
# File compound_J0000W.csv already exists
# idx = 273
# compound_files/KXDVXQIHJJNXFO-VDVKDMFPSA-N.pdb
# File compound_I000N5.csv already exists
# idx = 274
# compound_files/MOMXOJMYNNYSSO-HNNXBMFYSA-N.pdb
# File compound_T003XG.csv already exists
# idx = 275
# compound_files/LSVWEYNSNZJEGB-UHFFFAOYSA-N.pdb
# File compound_C004Z7.csv already exists
# idx = 276
# compound_files/DIZSSTIDZYLNBI-UHFFFAOYSA-N.pdb
# File compound_I0008D.csv already exists
# idx = 277
# compound_files/SZQHZHIPCJVCTP-UHFFFAOYSA-N.pdb
# File compound_T0063N.csv already exists
# idx = 278
# compound_files/MHVOJKFXMPOUON-UHFFFAOYSA-N.pdb
# File compound_T003U6.csv already exists
# idx = 279
# compound_files/MLNZGNREXNDJBQ-VQTJNVASSA-N.pdb
# File compound_T003VL.csv already exists
# idx = 280
# compound_files/OTQPSOHVLSUEKO-UHFFFAOYSA-N.pdb
# File compound_T004PJ.csv already exists
# idx = 281
# compound_files/PVFFNTOGDRKWHE-UHFFFAOYSA-N.pdb
# File compound_C101SX.csv already exists
# idx = 282
# compound_files/PAHKYLUYTGBFNW-CMDGGOBGSA-N.pdb
# File compound_T004SQ.csv already exists
# idx = 283
# compound_files/SJEDCBCUEIBPNB-UHFFFAOYSA-N.pdb
# File compound_C101S9.csv already exists
# idx = 284
# compound_files/FXNFHKRTJBSTCS-UHFFFAOYSA-N.pdb
# File compound_I000CD.csv already exists
# idx = 285
# compound_files/OXNCVPXHKUULSH-UHFFFAOYSA-N.pdb
# File compound_T004R4.csv already exists
# idx = 286
# compound_files/PKZSTHBGNYEKDH-GOTSBHOMSA-N.pdb
# File compound_C101QG.csv already exists
# idx = 287
# compound_files/FOYRFLMZVXPASD-UHFFFAOYSA-N.pdb
# File compound_T001L6.csv already exists
# idx = 288
# compound_files/BMGQMFHTPSJIIW-UHFFFAOYSA-N.pdb
# File compound_I00041.csv already exists
# idx = 289
# compound_files/MHAMAAKSVZMGHN-UHFFFAOYSA-N.pdb
# File compound_T003TS.csv already exists
# idx = 290
# compound_files/BUCKBHOWKWDMMK-UHFFFAOYSA-N.pdb
# File compound_I0004P.csv already exists
# idx = 291
# compound_files/MFXDNMBOOLLKDW-UHFFFAOYSA-N.pdb
# File compound_T003T2.csv already exists
# idx = 292
# compound_files/FQYRXINYPFFZAF-FUKCDUGKSA-N.pdb
# File compound_T001MD.csv already exists
# idx = 293
# compound_files/CKOYRIROPKBZLR-QORCZRPOSA-N.pdb
# File compound_I00069.csv already exists
# idx = 294
# compound_files/CAPZRPKPZMPEKQ-UHFFFAOYSA-N.pdb
# File compound_I0005C.csv already exists
# idx = 295
# compound_files/CRSZBBYHHDCMTP-UHFFFAOYSA-N.pdb
# File compound_I0006X.csv already exists
# idx = 296
# compound_files/OZTFBKUNJGXBOF-UHFFFAOYSA-N.pdb
# File compound_T004SF.csv already exists
# idx = 297
# compound_files/GEHLHDMDLCPKIW-QZTJIDSGSA-N.pdb
# GEHLHDMDLCPKIW-QZTJIDSGSA-N
# Failed to retrieve conformer IDs from PubChem.
# Problem processing SDF for file compound_T007OK.csv: cannot unpack non-iterable NoneType object
# idx = 298
# compound_files/FTQGQNXVAYRYQZ-UHFFFAOYSA-N.pdb
# File compound_I000C2.csv already exists
# idx = 299
# compound_files/OUTBUVLNDIYGFF-SJORKVTESA-N.pdb
# File compound_T004Q8.csv already exists
# idx = 300
# compound_files/FMEUIQVOTSTQBR-CRICUBBOSA-N.pdb
# FMEUIQVOTSTQBR-CRICUBBOSA-N
# Failed to retrieve conformer IDs from PubChem.
# Problem processing SDF for file compound_I000VE.csv: cannot unpack non-iterable NoneType object
# success = 282, exist = 0, failed = 7
# idx = 301
# compound_files/HNFIJWNVPWXSOL-UHFFFAOYSA-N.pdb
# File compound_C004UN.csv already exists
# idx = 302
# compound_files/MGJLLYMSYBFFFT-UHFFFAOYSA-N.pdb
# File compound_T003TD.csv already exists
# idx = 303
# compound_files/JCPBLVIGUOWOHW-UHFFFAOYSA-N.pdb
# File compound_C101P7.csv already exists
# idx = 304
# compound_files/OZSOIZBPXQYWQT-UYRXBGFRSA-N.pdb
# File compound_T004SD.csv already exists
# idx = 305
# compound_files/MIJPMFDJDTXPFB-UHFFFAOYSA-N.pdb
# File compound_T003UB.csv already exists
# idx = 306
# compound_files/ZLHYQWZCXWQCMC-UPHRSURJSA-N.pdb
# File compound_T00809.csv already exists
# idx = 307
# compound_files/MMDVXBYBUCASBB-QFIPXVFZSA-N.pdb
# File compound_T003VY.csv already exists
# idx = 308
# compound_files/ZMQYECIGILMMEL-UHFFFAOYSA-N.pdb
# File compound_T0080X.csv already exists
# idx = 309
# compound_files/UGODIOOKONOGOI-UHFFFAOYSA-N.pdb
# File compound_C004VW.csv already exists
# idx = 310
# compound_files/VHGJAFIHUSTRGB-UHFFFAOYSA-N.pdb
# File compound_C004V6.csv already exists
# idx = 311
# compound_files/BPYNPIYCDXZKTR-YPLLMFNKSA-N.pdb
# BPYNPIYCDXZKTR-YPLLMFNKSA-N
# Failed to retrieve conformer IDs from PubChem.
# Problem processing SDF for file compound_I0010O.csv: cannot unpack non-iterable NoneType object
# idx = 312
# compound_files/FSBMRSUSLBFNED-UHFFFAOYSA-N.pdb
# File compound_I000BU.csv already exists
# idx = 313
# compound_files/FXVFQWKPIVYPNN-VWLOTQADSA-N.pdb
# FXVFQWKPIVYPNN-VWLOTQADSA-N
# Failed to retrieve information from PubChem.
# Problem processing SDF for file compound_J100HI.csv: cannot unpack non-iterable NoneType object
# idx = 314
# compound_files/CGUCKNLIHKILNH-UHFFFAOYSA-N.pdb
# File compound_C101PA.csv already exists
# idx = 315
# compound_files/KWGRBVOPPLSCSI-WCBMZHEXSA-N.pdb
# File compound_C003R8.csv already exists
# idx = 316
# compound_files/PAJSJBLTHMYPMY-UHFFFAOYSA-N.pdb
# File compound_T004SS.csv already exists
# idx = 317
# compound_files/DNUZGOCLFBAJAL-HNNXBMFYSA-N.pdb
# File compound_T0018Z.csv already exists
# idx = 318
# compound_files/CFGADNMKHAGYEI-ZETCQYMHSA-N.pdb
# File compound_I0005V.csv already exists
# idx = 319
# compound_files/ZMKIAFJBCJTUFC-CUNXSJBXSA-N.pdb
# File compound_T0080O.csv already exists
# idx = 320
# compound_files/FROQCGUHFCMLBP-UHFFFAOYSA-N.pdb
# File compound_T001MQ.csv already exists
# idx = 321
# compound_files/FTSOGSFFYMFUDT-UHFFFAOYSA-N.pdb
# File compound_T001NJ.csv already exists
# idx = 322
# compound_files/ZOMDPFRLBCLEDW-IBGZPJMESA-N.pdb
# File compound_T00821.csv already exists
# idx = 323
# compound_files/CXVUEKICGYNMBG-UHFFFAOYSA-N.pdb
# File compound_I0007I.csv already exists
# idx = 324
# compound_files/MGXPOFVTTBGHSC-UHFFFAOYSA-N.pdb
# File compound_T003TQ.csv already exists
# idx = 325
# compound_files/FOXOPJJICTTZEU-XBXARRHUSA-N.pdb
# File compound_T001L4.csv already exists
# idx = 326
# compound_files/VBHVOJJDISNENC-VEXWJQHLSA-N.pdb
# File compound_T006JS.csv already exists
# idx = 327
# compound_files/DKIPXVAZUQYHHQ-UHFFFAOYSA-N.pdb
# File compound_T00174.csv already exists
# idx = 328
# compound_files/DRFJVMVOQRNXTR-UHFFFAOYSA-N.pdb
# File compound_I0009B.csv already exists
# idx = 329
# compound_files/DPTXHVXUQXOZLC-HOFKKMOUSA-N.pdb
# File compound_T001AE.csv already exists
# idx = 330
# compound_files/SRCAHUCFNDYNBV-QFIPXVFZSA-N.pdb
# File compound_T00606.csv already exists
# idx = 331
# compound_files/SSYLLNMYBQFPCH-DFBJGRDBSA-N.pdb
# File compound_T0060W.csv already exists
# idx = 332
# compound_files/MRIAQLRQZPPODS-UHFFFAOYSA-N.pdb
# File compound_C001D7.csv already exists
# idx = 333
# compound_files/LDSUSZTYDPJIIM-MDKPJZGXSA-N.pdb
# File compound_I000NV.csv already exists
# idx = 334
# compound_files/BFGIYZZPFRGARH-UHFFFAOYSA-N.pdb
# File compound_J0000U.csv already exists
# idx = 335
# compound_files/BPXTVKJDWFUPCM-UHFFFAOYSA-N.pdb
# File compound_J00004.csv already exists
# idx = 336
# compound_files/UTRBTIFHRKMFMU-UPVQGACJSA-N.pdb
# File compound_T006GT.csv already exists
# idx = 337
# compound_files/PVIKSBZFUSEAMF-UHFFFAOYSA-N.pdb
# File compound_C001EE.csv already exists
# idx = 338
# compound_files/LISDIDPRLJMBPJ-NTFMPISFSA-N.pdb
# File compound_I000OE.csv already exists
# idx = 339
# compound_files/DDLIGBOFAVUZHB-UHFFFAOYSA-N.pdb
# File compound_T00148.csv already exists
# idx = 340
# compound_files/DLBHIUWUQMPJLY-PXNSSMCTSA-N.pdb
# File compound_T0017B.csv already exists
# idx = 341
# compound_files/DUPPPHNZCVQSQO-NTFMPISFSA-N.pdb
# File compound_I0009U.csv already exists
# idx = 342
# compound_files/DEGQRJCTRCTPIT-KRWDZBQOSA-N.pdb
# File compound_I00080.csv already exists
# idx = 343
# compound_files/PHINNLAJTUGZSZ-HXUWFJFHSA-N.pdb
# File compound_J000F3.csv already exists
# idx = 344
# compound_files/VDRHHZQQKHUNMM-UHFFFAOYSA-N.pdb
# File compound_J000EI.csv already exists
# idx = 345
# compound_files/FNLHOPZUOLWLFS-UHFFFAOYSA-N.pdb
# File compound_J00038.csv already exists
# idx = 346
# compound_files/PNJPCIYMKXINDN-AWEZNQCLSA-N.pdb
# PNJPCIYMKXINDN-AWEZNQCLSA-N
# Failed to retrieve conformer IDs from PubChem.
# Problem processing SDF for file compound_I001ED.csv: cannot unpack non-iterable NoneType object
# idx = 347
# compound_files/QINUJAURWORMBP-KRWDZBQOSA-N.pdb
# QINUJAURWORMBP-KRWDZBQOSA-N
# Failed to retrieve conformer IDs from PubChem.
# Problem processing SDF for file compound_I001EE.csv: cannot unpack non-iterable NoneType object
# idx = 348
# compound_files/VRIFJRKPGQZHJW-UHFFFAOYSA-N.pdb
# File compound_T006RB.csv already exists
# idx = 349
# compound_files/CCXSXGXXIGHRHJ-UHFFFAOYSA-N.pdb
# File compound_C003KL.csv already exists
# idx = 350
# compound_files/VQVVXSALLAVZRC-XVNBXDOJSA-N.pdb
# File compound_T006QY.csv already exists
# success = 328, exist = 0, failed = 11
# idx = 351
# compound_files/OHYSAAPBMBXXQQ-JZJYNLBNSA-N.pdb
# OHYSAAPBMBXXQQ-JZJYNLBNSA-N
# Failed to retrieve information from PubChem.
# Problem processing SDF for file compound_J000F1.csv: cannot unpack non-iterable NoneType object
# idx = 352
# compound_files/LVCFWVYKKRGZFQ-UHFFFAOYSA-N.pdb
# File compound_T003NH.csv already exists
# idx = 353
# compound_files/LTTIHWWYCLBIKC-UHFFFAOYSA-N.pdb
# File compound_T003MS.csv already exists
# idx = 354
# compound_files/GLFIMTCZHOPZNZ-UHFFFAOYSA-N.pdb
# File compound_T001VL.csv already exists
# idx = 355
# compound_files/ODFWEQUMDQJBJZ-IBGZPJMESA-N.pdb
# File compound_T004HN.csv already exists
# idx = 356
# compound_files/QKQSHKXIHWMZBP-UHFFFAOYSA-N.pdb
# File compound_I000ZD.csv already exists
# idx = 357
# Failed to retrieve information from PubChem.
# Problem processing SDF for file compound_T003Z8.csv: cannot unpack non-iterable NoneType object
# idx = 358
# compound_files/GMZQXSJOGNIVAK-VXKWHMMOSA-N.pdb
# File compound_T001WH.csv already exists
# idx = 359
# compound_files/HAEPCRQCUOJIAG-UHFFFAOYSA-N.pdb
# HAEPCRQCUOJIAG-UHFFFAOYSA-N
# compound_files/MXSJSHDIEDILST-UHFFFAOYSA-N.pdb
# File compound_T0041Q.csv already exists
# idx = 360
# compound_files/KJTGODHDGKRMDH-NRFANRHFSA-N.pdb
# File compound_T00376.csv already exists
# idx = 361
# compound_files/SFDROHXKTATJBI-UHFFFAOYSA-N.pdb
# File compound_C101GH.csv already exists
# idx = 362
# compound_files/NKWCTBQGEYIWFO-INIZCTEOSA-N.pdb
# File compound_I000TO.csv already exists
# idx = 363
# compound_files/KGICILLGXCZOKO-HJWJTTGWSA-N.pdb
# File compound_T00362.csv already exists
# idx = 364
# compound_files/OCOGLIXGSRGDAK-SFHVURJKSA-N.pdb
# OCOGLIXGSRGDAK-SFHVURJKSA-N
# Compound ID (CID): 168318225Failed to retrieve conformer IDs from PubChem.
# Problem processing SDF for file compound_C003GM.csv: cannot unpack non-iterable NoneType object
# idx = 365
#
# compound_files/GPDBRNCVMGUGBS-UHFFFAOYSA-N.pdb
# File compound_T001XG.csv already exists
# idx = 366
# compound_files/KQSBZNJFKWOQQK-UHFFFAOYSA-N.pdb
# File compound_T003A1.csv already exists
# idx = 367
# compound_files/KUAQHDLCRHDEOT-UZYVYHOESA-N.pdb
# KUAQHDLCRHDEOT-UZYVYHOESA-N
# Failed to retrieve conformer IDs from PubChem.
# Problem processing SDF for file compound_I001IQ.csv: cannot unpack non-iterable NoneType object
# idx = 368
# compound_files/NICLDNFOUWEYPY-UHFFFAOYSA-N.pdb
# File compound_J100F6.csv already exists
# idx = 369
# compound_files/CDSKYCWTQPDDMJ-ODLFYWEKSA-N.pdb
# File compound_T000RD.csv already exists
# idx = 370
# compound_files/VPWYYBNJVIFKDC-UHFFFAOYSA-N.pdb
# File compound_C005H0.csv already exists
# idx = 371
# compound_files/QMSXSEJLMHGKCI-IBGZPJMESA-N.pdb
# File compound_T0059M.csv already exists
# idx = 372
# compound_files/FEQUIPXIENTMJN-GOSISDBHSA-N.pdb
# File compound_P0003W.csv already exists
# idx = 373
# compound_files/ALXMSKACQCRMOE-UHFFFAOYSA-N.pdb
# File compound_P0000L.csv already exists
# idx = 374
# compound_files/ZLOXYEZYWCTXHU-UHFFFAOYSA-N.pdb
# File compound_C002NW.csv already exists
# idx = 375
# compound_files/GZRJCYVPKHGRLM-MTJSOVHGSA-N.pdb
# File compound_C000UH.csv already exists
# idx = 376
# compound_files/AVHKGLBWQBMEGS-UHFFFAOYSA-N.pdb
# File compound_C100OT.csv already exists
# idx = 377
# compound_files/CBTICXFNIGNHEP-UHFFFAOYSA-N.pdb
# File compound_C100LO.csv already exists
# idx = 378
# compound_files/CUBGJWXDIQEMAV-UHFFFAOYSA-N.pdb
# File compound_P0002S.csv already exists
# idx = 379
# compound_files/BXFSSYQFFSWQEA-UHFFFAOYSA-N.pdb
# File compound_P00022.csv already exists
# idx = 380
# compound_files/BIIVYFLTOXDAOV-YVEFUNNKSA-N.pdb
# File compound_P0001H.csv already exists
# idx = 381
# compound_files/UEGSVADLZPXOAG-SXLOBPIMSA-N.pdb
# File compound_P000G9.csv already exists
# idx = 382
# compound_files/UVWAIBUOXKRXQY-UHFFFAOYSA-N.pdb
# File compound_P000GX.csv already exists
# idx = 383
# compound_files/QKIZLQASTHBCLZ-UHFFFAOYSA-N.pdb
# File compound_T0058I.csv already exists
# idx = 384
# compound_files/UEFBMKGVQXOXRD-INIZCTEOSA-N.pdb
# File compound_C005IU.csv already exists
# idx = 385
# compound_files/RHOOHUMOHVIXEF-UHFFFAOYSA-N.pdb
# File compound_P000E1.csv already exists
# idx = 386
# compound_files/SRQYLNYQAPCPIR-UHFFFAOYSA-N.pdb
# File compound_P000FK.csv already exists
# idx = 387
# compound_files/RWDOZZPKEZJESZ-UHFFFAOYSA-N.pdb
# File compound_P000EP.csv already exists
# idx = 388
# compound_files/CCEPCRZUBCXDIG-FQEVSTJZSA-N.pdb
# File compound_T000QH.csv already exists
# idx = 389
# compound_files/GOYKPTVODBAOPR-UHFFFAOYSA-N.pdb
# File compound_C005HF.csv already exists
# idx = 390
# compound_files/YUOMCSBLOMSMSI-BQPXYCOLSA-N.pdb
# File compound_T007TU.csv already exists
# idx = 391
# compound_files/YGJHOWOEBFBOSF-UHFFFAOYSA-N.pdb
# File compound_C100L9.csv already exists
# idx = 392
# compound_files/YTKGKCKBCJZBIX-UHFFFAOYSA-N.pdb
# File compound_T007T4.csv already exists
# idx = 393
# compound_files/ZBPWDXMZTZUZSY-UHFFFAOYSA-N.pdb
# File compound_T007WN.csv already exists
# idx = 394
# compound_files/CHAKVDDAHQGTLR-IBGZPJMESA-N.pdb
# File compound_P0002D.csv already exists
# idx = 395
# compound_files/RMYCOIJZFBFFLU-UHFFFAOYSA-N.pdb
# File compound_T005M4.csv already exists
# idx = 396
# compound_files/YWSLINMGMAAMNG-SSDVNMTOSA-N.pdb
# File compound_T007UQ.csv already exists
# idx = 397
# compound_files/GVZXSZWCZGKLRS-UHFFFAOYSA-N.pdb
# File compound_C002OD.csv already exists
# idx = 398
# compound_files/CAXFSIWSCHLEMR-UHFFFAOYSA-N.pdb
# File compound_T000PL.csv already exists
# idx = 399
# compound_files/XOWBHNIRCZERRH-UHFFFAOYSA-N.pdb
# File compound_C005J8.csv already exists
# idx = 400
# compound_files/INGQKBOOCCZMBG-UHFFFAOYSA-N.pdb
# File compound_T002KS.csv already exists
# success = 374, exist = 0, failed = 15
# idx = 401
# compound_files/PHEZBZSOCLLNEW-UHFFFAOYSA-N.pdb
# File compound_C0029T.csv already exists
# idx = 402
# compound_files/RCOJVDOCGJOAAU-UHFFFAOYSA-N.pdb
# File compound_P000DT.csv already exists
# idx = 403
# compound_files/WOSGOHDUUBVSBO-UHFFFAOYSA-O.pdb
# File compound_P000ID.csv already exists
# idx = 404
# compound_files/DCNZODDMKOTPHQ-UHFFFAOYSA-N.pdb
# File compound_C00518.csv already exists
# idx = 405
# compound_files/GXJXAWVNCAMOFX-UHFFFAOYSA-N.pdb
# File compound_T0020S.csv already exists
# idx = 406
# compound_files/GZMUQYDHCNSVFL-DEOSSOPVSA-N.pdb
# File compound_T0021W.csv already exists
# idx = 407
# compound_files/OWEYQIARHXPFES-UHFFFAOYSA-N.pdb
# File compound_C10079.csv already exists
# idx = 408
# compound_files/IAZNDXVEAROTIW-UHFFFAOYSA-N.pdb
# File compound_C005E7.csv already exists
# idx = 409
# compound_files/IDKGSEXQIHVYLO-PIJUOVFKSA-N.pdb
# File compound_T002FT.csv already exists
# idx = 410
# compound_files/WZBIMVSWUWZIHN-UHFFFAOYSA-N.pdb
# File compound_P000IS.csv already exists
# idx = 411
# compound_files/QULYZHFZLOZQQS-UHFFFAOYSA-N.pdb
# File compound_T005CI.csv already exists
# idx = 412
# compound_files/UZLNHXVIIXNLFM-UHFFFAOYSA-N.pdb
# File compound_P000H6.csv already exists
# idx = 413
# compound_files/IMPOOMVZVWKSAP-UHFFFAOYSA-N.pdb
# IMPOOMVZVWKSAP-UHFFFAOYSA-N
# Compound ID (CID): 168318071
# Compound ID (CID): 168318255
# Compound ID (CID): 168317952
# Compound ID (CID): 168318333
# Compound ID (CID): 168317880
# Failed to retrieve conformer IDs from PubChem.
# Problem processing SDF for file compound_I000CS.csv: cannot unpack non-iterable NoneType object
# idx = 414
# Failed to retrieve conformer IDs from PubChem.
# Problem processing SDF for file compound_I0008S.csv: cannot unpack non-iterable NoneType object
# idx = 415
# compound_files/YTFPNQZFSVSZGW-UHFFFAOYSA-N.pdb
# compound_files/IETLYQVKZKEMKL-FZFLATATSA-N.pdb
# File compound_T002GP.csv already exists
# idx = 416
# File compound_I001GN.csv already exists
# idx = 417
# compound_files/XEKOYBDMUHMXBJ-KGLIPLIRSA-N.pdb
# File compound_I001D4.csv already exists
# idx = 418
# compound_files/BNFSEAYFTNCGLP-UHFFFAOYSA-N.pdb
# File compound_T000JB.csv already exists
# idx = 419
# compound_files/RTIXKCRFFJGDFG-UHFFFAOYSA-N.pdb
# File compound_I0012E.csv already exists
# idx = 420
# compound_files/BLZOWNLJBLDRTL-UHFFFAOYSA-N.pdb
# File compound_T000IY.csv already exists
# idx = 421
# compound_files/ISZIRXMFUSQQOS-NDXORKPFSA-N.pdb
# compound_files/QJMFRYJQORRYQW-UHFFFAOYSA-N.pdb
# File compound_C1029F.csv already exists
# idx = 422
# File compound_C1028B.csv already exists
# idx = 423
# compound_files/OJZZJTLBYXHUSJ-UHFFFAOYSA-N.pdb
# compound_files/RBKSLBLKMUKBOV-SWGQDTFXSA-N.pdb
# File compound_C0009A.csv already exists
# idx = 424
# File compound_I0010Z.csv already exists
# idx = 425
# compound_files/QAIPRVGONGVQAS-DUXPYHPUSA-N.pdb
# compound_files/YWLPUGZLVNRBSU-UHFFFAOYSA-N.pdb
# File compound_C000O0.csv already exists
# idx = 426
# File compound_I001GY.csv already exists
# idx = 427
# compound_files/XGGOZVAZONWKNW-JKFKMHIGSA-N.pdb
# compound_files/YKLQLVYNTFHTHL-YXYSEUPNSA-N.pdb
# XGGOZVAZONWKNW-JKFKMHIGSA-N
# File compound_T007OH.csv already exists
# idx = 428
# compound_files/GQFHRKAYWMSFGN-UHFFFAOYSA-N.pdb
# File compound_C1029Q.csv already exists
# idx = 429
# compound_files/JBIMMGGXACSHDI-INIZCTEOSA-N.pdb
# File compound_T002R0.csv already exists
# idx = 430
# compound_files/ZFMZWYQYVCPKDJ-UHFFFAOYSA-N.pdb
# File compound_C1028U.csv already exists
# idx = 431
# compound_files/QXXQFKJYCHTAPB-UHFFFAOYSA-N.pdb
# File compound_I0010M.csv already exists
# idx = 432
# Compound ID (CID): 168318247
# compound_files/SDGNLJQANKDFMF-DEOSSOPVSA-N.pdb
# SDGNLJQANKDFMF-DEOSSOPVSA-N
# Compound ID (CID): 168318211
# Failed to retrieve conformer IDs from PubChem.
# Problem processing SDF for file compound_I000Z2.csv: cannot unpack non-iterable NoneType object
# idx = 433
# compound_files/JGKQCWNXJDBDJO-UHFFFAOYSA-N.pdb
# File compound_T002SU.csv already exists
# idx = 434
# compound_files/BQSRERXVYLPKDS-IBGZPJMESA-N.pdb
# File compound_T000KQ.csv already exists
# idx = 435
# compound_files/SHWNHVGERLWSSM-INIZCTEOSA-N.pdb
# File compound_T005VH.csv already exists
# idx = 436
# compound_files/AAAKBEWYWAMEEW-UHFFFAOYSA-N.pdb
# File compound_T00000.csv already exists
# idx = 437
# compound_files/BDNRWQDKTWLRRO-UHFFFAOYSA-N.pdb
# File compound_T000EZ.csv already exists
# idx = 438
# compound_files/GERBHAWOLATBEK-UHFFFAOYSA-N.pdb
# File compound_C1025E.csv already exists
# idx = 439
# compound_files/WWWJNTZPXCPXAB-UHFFFAOYSA-N.pdb
# File compound_T0076W.csv already exists
# idx = 440
# compound_files/WYYLCRHWQCODSD-KRWDZBQOSA-N.pdb
# File compound_T0077S.csv already exists
# idx = 441
# compound_files/WSOUGGSZELMEFW-UHFFFAOYSA-N.pdb
# File compound_T0074H.csv already exists
# idx = 442
# compound_files/AESXNYDCOYLGAH-SJORKVTESA-N.pdb
# File compound_T0002N.csv already exists
# idx = 443
# compound_files/SNPUAXHAZYUTDJ-UHFFFAOYSA-N.pdb
# File compound_T005YG.csv already exists
# idx = 444
# compound_files/ABLODAASGXFFPC-UHFFFAOYSA-N.pdb
# File compound_T0000F.csv already exists
# idx = 445
# compound_files/XKSSBLZLZBCROG-LBPRGKRZSA-N.pdb
# File compound_T007CK.csv already exists
# idx = 446
# compound_files/FRADTKAUXQUOIJ-UHFFFAOYSA-N.pdb
# File compound_C000AZ.csv already exists
# idx = 447
# compound_files/BFJJEUZCSKYLAS-UHFFFAOYSA-N.pdb
# File compound_T000FV.csv already exists
# idx = 448
# compound_files/DGHMWFXLUQFCNT-UHFFFAOYSA-N.pdb
# File compound_C1024V.csv already exists
# idx = 449
# compound_files/BAPMCCLJYXUNAN-INIZCTEOSA-N.pdb
# File compound_T000DI.csv already exists
# idx = 450
# compound_files/WXSHDDWPXWECMG-LBPRGKRZSA-N.pdb
# File compound_T0077D.csv already exists
# success = 421, exist = 0, failed = 18
# idx = 451
# compound_files/WXSHDDWPXWECMG-LBPRGKRZSA-N.pdb
# File compound_T0077E.csv already exists
# idx = 452
# compound_files/BHDLQEOXHBGVFT-SFHVURJKSA-N.pdb
# File compound_T000GS.csv already exists
# idx = 453
# compound_files/SQIDFFKYMURYAR-SFHVURJKSA-N.pdb
# File compound_T005ZJ.csv already exists
# idx = 454
# compound_files/SNCOENIEQCFFEY-OYDLWJJNSA-N.pdb
# File compound_T005Y0.csv already exists
# idx = 455
# compound_files/ZHLIBGVCPIYWGR-UHFFFAOYSA-N.pdb
# File compound_I001ID.csv already exists
# idx = 456
# compound_files/AEHRNUUXNPGMHM-KRWDZBQOSA-N.pdb
# File compound_T00029.csv already exists
# idx = 457
# compound_files/XKSSBLZLZBCROG-LBPRGKRZSA-N.pdb
# File compound_T007CJ.csv already exists
# idx = 458
# compound_files/BCZJAKMDVNIASQ-UHFFFAOYSA-N.pdb
# File compound_T000EL.csv already exists
# idx = 459
# compound_files/BDYCPXWUAKXQDL-QFIPXVFZSA-N.pdb
# File compound_T000F6.csv already exists
# idx = 460
# compound_files/KQWVAUSXZDRQPZ-OREGWCPLSA-N.pdb
# File compound_C0007K.csv already exists
# idx = 461
# compound_files/YYVYAPXYZVYDHN-UHFFFAOYSA-N.pdb
# File compound_C00069.csv already exists
# idx = 462
# compound_files/WYPHONGBLYVSCW-QMMMGPOBSA-N.pdb
# File compound_T0077R.csv already exists
# idx = 463
# compound_files/XJIREEHRSUICRY-DEOSSOPVSA-N.pdb
# File compound_T007BY.csv already exists
# idx = 464
# compound_files/ZNARIMRWAILYDS-SJORKVTESA-N.pdb
# File compound_I001IS.csv already exists
# idx = 465
# PLIYSHLLWGTRBD-UHFFFAOYSA-N
# Compound ID (CID): 700307Failed to retrieve information from PubChem.
# Problem processing SDF for file compound_C0013L.csv: cannot unpack non-iterable NoneType object
#
# Failed to retrieve SDF data from PubChem.
# Problem processing SDF for file compound_C001GT.csv: cannot unpack non-iterable NoneType object
# idx = 3591
# idx = 3592
# compound_files/OTHBPHKCEOODOA-UHFFFAOYSA-N.pdb
# compound_files/FPRXGNGLIQZNBP-KRWDZBQOSA-N.pdb
# File compound_T001LL.csv already exists
# idx = 3593
# OTHBPHKCEOODOA-UHFFFAOYSA-N
# compound_files/PKMOCFPDFBAKKL-KPJFUTMLSA-M.pdb
# PKMOCFPDFBAKKL-KPJFUTMLSA-M
# Failed to retrieve SDF data from PubChem.
# Problem processing SDF for file compound_J0000L.csv: cannot unpack non-iterable NoneType object
# idx = 3594
# compound_files/FUIHSLXOHKGZPY-UHFFFAOYSA-N.pdb
# File compound_T001NS.csv already exists
# idx = 3595
# compound_files/AQFFXPQJLZFABJ-UHFFFAOYSA-N.pdb
# AQFFXPQJLZFABJ-UHFFFAOYSA-N
# Processed compound_files/KOYJTNWWQYXATJ-UHFFFAOYSA-N.pdb
# idx = 3596
# compound_files/OSSJJUINWCSLDC-UHFFFAOYSA-N.pdb
# OSSJJUINWCSLDC-UHFFFAOYSA-N
# Processed compound_files/LXBIFEVIBLOUGU-ARQDHWQXSA-N.pdb
# Compound ID (CID): 1963306
# Compound ID (CID): 809513
# Processed compound_files/GNNCNKKBHNXZED-UHFFFAOYSA-N.pdb
# Compound ID (CID): 5864175
# Compound ID (CID): 16286864
# Compound ID (CID): 22064769
# Compound ID (CID): 145960334
# Compound ID (CID): 119461
# Compound ID (CID): 44365384
# First Conformer ID: 000AAF9300000001
# Compound ID (CID): 45110127
# First Conformer ID: 000C5A2900000001
# First Conformer ID: 001DF52A00000001
# Failed to retrieve conformer IDs from PubChem.Failed to retrieve conformer IDs from PubChem.
# Problem processing SDF for file compound_C001HL.csv: cannot unpack non-iterable NoneType object
#
# Problem processing SDF for file compound_T004R8.csv: cannot unpack non-iterable NoneType object
# First Conformer ID: 00F8849000000001
# First Conformer ID: 0001D2A500000001First Conformer ID: 02A4F64800000001
# Failed to retrieve conformer IDs from PubChem.
# Problem processing SDF for file compound_J000HW.csv: cannot unpack non-iterable NoneType object
#
# First Conformer ID: 02B0536F00000002
# Processed compound_files/GQNGIQUHBDDNMN-UHFFFAOYSA-N.pdb
# Failed to retrieve SDF data from PubChem.
# Problem processing SDF for file compound_C001FG.csv: cannot unpack non-iterable NoneType object
# Processed compound_files/UJNCDCNAKQUXAW-UHFFFAOYSA-N.pdb
# Processed compound_files/PLIYSHLLWGTRBD-UHFFFAOYSA-N.pdb
# Processed compound_files/AQFFXPQJLZFABJ-UHFFFAOYSA-N.pdb
# Processed compound_files/OTHBPHKCEOODOA-UHFFFAOYSA-N.pdb
# Processed compound_files/OSSJJUINWCSLDC-UHFFFAOYSA-N.pdb
# success = 2608, exist = 0, failed = 987
