# %%
import requests
import os

def search_protein_family(family_name):
    family_name = family_name.replace(" ", "+")
    base_url = f"https://rest.uniprot.org/uniprotkb/search?fields=accession%2Cid%2Cprotein_name%2Cgene_names%2Corganism_name%2Clength%2Creviewed&format=tsv&query=%28%28taxonomy_id%3A9606%29+AND+%22{family_name}%22%29&size=500"

    response = requests.get(base_url)

    if response.status_code == 200:
        lines = response.text.strip().split("\n")
        uniprot_ids = lines[1:]  # Skip the header line
        return uniprot_ids
    else:
        print(f"Error: {response.status_code}")
        return []

def download_pdb_files(family_name, top_n=5, download_directory="."):

    number_of_files = len([name for name in os.listdir(download_directory) if os.path.isfile(os.path.join(download_directory, name))])
    if number_of_files >= top_n:
        print(f"Already downloaded {top_n} files for protein family {family_name}")
        return
    elif number_of_files>0:
        print(f"Already downloaded {number_of_files} files for protein family {family_name}")
        top_n = top_n - number_of_files
    success=0
    uniprot_data = search_protein_family(family_name)
    for line in uniprot_data:
        try:
            uniprot_id = line.split("\t")[0]
            alphafold_url = f"https://alphafold.ebi.ac.uk/api/prediction/{uniprot_id}"
            response = requests.get(alphafold_url)
            pdb_url = response.json()[0]["pdbUrl"]
            pdb_file = requests.get(pdb_url)
            with open(f"{download_directory}/{uniprot_id}.pdb", "wb") as f:
                f.write(pdb_file.content)
            print(f"Downloaded {uniprot_id}.pdb in protein family {family_name}")
            success+=1
        except:
            print(f"Failed to download {uniprot_id}.pdb in protein family {family_name}")
            pass
        ongoing_num_files = len([name for name in os.listdir(download_directory) if os.path.isfile(os.path.join(download_directory, name))])
        if(ongoing_num_files==top_n):
            break
fail = {'Amyloid beta A4 precursor protein-binding family A member 1',
 'BCL-like',
 'Bcl-2-like protein 11',
 'CD74 (Macrophage migration inhibitory factor and HLA-DR antigens-associated invariant chain)',
 'Cyclin-dependent kinases regulatory subunit 1',
 'Endothelial PAS domain-containing protein 1',
 'Guanine nucleotide-binding protein G(i) subunit alpha-1',
 'MKEAP1',
 'MNRF2',
 'Mixed-lineage leukemia 1 (MLL1)',
 'Nuclear receptor coactivator 2',
 'Nuclear receptor coactivator 3',
 'PB1-5',
 'Perilipin-1',
 'Perilipin-5',
 'S100-A10',
 'TNFB',
 'TNFR1A',
 'VEGFR3',
 'Voltage-gated N-type calcium channel alpha-1B subunit',
 'XDM2',
 'ZIPA'}
# Example usage
top_n = 5
folder = "protein_files"
for filename in os.listdir(folder):
    filepath = os.path.join(folder, filename)
    if not os.path.isdir(filepath):
        continue
    for family_name in os.listdir(filepath):
        family_path = os.path.join(filepath, family_name)
        if not os.path.isdir(family_path):
            continue
        if family_name in fail:
            download_pdb_files(family_name, top_n, family_path)
# Out:
# Already downloaded 3 files for protein family TNFB
# Downloaded P01374.pdb in protein family TNFB
# Downloaded P19438.pdb in protein family TNFB
# Downloaded Q7KYK3.pdb in protein family TNFB
# Already downloaded 4 files for protein family TNFR1A
# Downloaded P19438.pdb in protein family TNFR1A
# Downloaded J9PH39.pdb in protein family TNFR1A
# Downloaded F5H6V7.pdb in protein family TNFR1A
# Downloaded F5H8A6.pdb in protein family TNFR1A
# Already downloaded 2 files for protein family Perilipin-5
# Downloaded Q00G26.pdb in protein family Perilipin-5
# Downloaded K7EIX1.pdb in protein family Perilipin-5
# Already downloaded 4 files for protein family Bcl-2-like protein 11
# Downloaded O43521.pdb in protein family Bcl-2-like protein 11
# Downloaded E9PAM9.pdb in protein family Bcl-2-like protein 11
# Downloaded H7BZE5.pdb in protein family Bcl-2-like protein 11
# Downloaded C9J417.pdb in protein family Bcl-2-like protein 11
# Already downloaded 3 files for protein family Nuclear receptor coactivator 2
# Downloaded Q9NPJ4.pdb in protein family Nuclear receptor coactivator 2
# Downloaded Q15596.pdb in protein family Nuclear receptor coactivator 2
# Failed to download H0YBB6.pdb in protein family Nuclear receptor coactivator 2
# Failed to download A0A1D5RMT0.pdb in protein family Nuclear receptor coactivator 2
# Downloaded E5RFN9.pdb in protein family Nuclear receptor coactivator 2
# Downloaded E7EWM1.pdb in protein family Nuclear receptor coactivator 2
# Downloaded A0A0B6XJZ8.pdb in protein family Nuclear receptor coactivator 2
# Downloaded J3KS97.pdb in protein family Nuclear receptor coactivator 2
# Downloaded B4DPW8.pdb in protein family Nuclear receptor coactivator 2
# Downloaded Q569J4.pdb in protein family Nuclear receptor coactivator 2
# Already downloaded 4 files for protein family S100-A10
# Downloaded P60903.pdb in protein family S100-A10
# Downloaded P07355.pdb in protein family S100-A10
# Failed to download Q09666.pdb in protein family S100-A10
# Downloaded Q14527.pdb in protein family S100-A10
# Downloaded Q6FGE5.pdb in protein family S100-A10
# Already downloaded 4 files for protein family Nuclear receptor coactivator 3
# Downloaded Q9Y6Q9.pdb in protein family Nuclear receptor coactivator 3
# Failed to download Q59EE8.pdb in protein family Nuclear receptor coactivator 3
# Downloaded B4DYS9.pdb in protein family Nuclear receptor coactivator 3
# Downloaded B4DL21.pdb in protein family Nuclear receptor coactivator 3
# Downloaded B4DYT5.pdb in protein family Nuclear receptor coactivator 3
# Failed to download Q0IIN7.pdb in protein family Nuclear receptor coactivator 3
# Failed to download Q569F6.pdb in protein family Nuclear receptor coactivator 3
# Failed to download A8K0W8.pdb in protein family Nuclear receptor coactivator 3
# Failed to download Q65ZG9.pdb in protein family Nuclear receptor coactivator 3
# Already downloaded 4 files for protein family Endothelial PAS domain-containing protein 1
# Downloaded Q99814.pdb in protein family Endothelial PAS domain-containing protein 1
# Downloaded B3KW07.pdb in protein family Endothelial PAS domain-containing protein 1
# Downloaded C9J9N2.pdb in protein family Endothelial PAS domain-containing protein 1
# Downloaded Q53SM6.pdb in protein family Endothelial PAS domain-containing protein 1
# Already downloaded 3 files for protein family Amyloid beta A4 precursor protein-binding family A member 1
# Downloaded Q02410.pdb in protein family Amyloid beta A4 precursor protein-binding family A member 1
# Downloaded A0A0G2JMD7.pdb in protein family Amyloid beta A4 precursor protein-binding family A member 1
# Downloaded A0A0D9SFA9.pdb in protein family Amyloid beta A4 precursor protein-binding family A member 1
# Failed to download A0A8V8TPS8.pdb in protein family Amyloid beta A4 precursor protein-binding family A member 1
# Already downloaded 4 files for protein family VEGFR3
# Downloaded P35916.pdb in protein family VEGFR3
# Downloaded P49767.pdb in protein family VEGFR3
# Downloaded B5A927.pdb in protein family VEGFR3
# Downloaded B5A928.pdb in protein family VEGFR3
# Failed to download E9PD35.pdb in protein family VEGFR3
# Already downloaded 3 files for protein family Perilipin-1
# Downloaded O60240.pdb in protein family Perilipin-1
# Downloaded O14520.pdb in protein family Perilipin-1
# Downloaded H0YM16.pdb in protein family Perilipin-1
# Already downloaded 2 files for protein family Guanine nucleotide-binding protein G(i) subunit alpha-1
# Downloaded P63096.pdb in protein family Guanine nucleotide-binding protein G(i) subunit alpha-1
# Failed to download A0A3B3ITM0.pdb in protein family Guanine nucleotide-binding protein G(i) subunit alpha-1
# Downloaded A0A3B3IUA8.pdb in protein family Guanine nucleotide-binding protein G(i) subunit alpha-1
# Already downloaded 1 files for protein family Cyclin-dependent kinases regulatory subunit 1
# Downloaded P61024.pdb in protein family Cyclin-dependent kinases regulatory subunit 1
# Failed to download Q03164.pdb in protein family Mixed-lineage leukemia 1 (MLL1)
